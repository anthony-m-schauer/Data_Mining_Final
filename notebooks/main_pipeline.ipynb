# %% [markdown]
# from data_pipeline import *
# from similarity import *
# from clustering import *
# from visuals import *
#
# # 1. Download Data
# # prices = download_snp500_prices(tickers, start_date, end_date)
#
# # 2. Compute Returns
# # returns = compute_daily_returns(prices)
#
# # 3. Normalize Returns
# # normalized = normalize_returns(returns)
#
# # 4. Compute Similarity
# # pearson_matrix = compute_pearson(normalized)
#
# # 5. Cluster
# # kmeans_labels = run_kmeans(normalized, k=5)
#
# # 6. Visualize
# # plot_heatmap(pearson_matrix)
